# %%
from MNIST import main_2
# Out:
# d:\miniconda3\Lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] 找不到指定的程序。'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
from MNIST import main
# Out:
# d:\miniconda3\Lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] 找不到指定的程序。'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# Decrease d from 64 to 10(by narrow method to adjust)

# %%
main(contact = True, overlap=True,m=8,stride = 4,s=10)
# Out:
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[1000],loss:1.656
# epochs:[0],iteration:[250]/[1000],loss:0.341
# epochs:[0],iteration:[500]/[1000],loss:0.251
# epochs:[0],iteration:[750]/[1000],loss:0.231
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[1000],loss:0.224
# epochs:[1],iteration:[250]/[1000],loss:0.211
# epochs:[1],iteration:[500]/[1000],loss:0.212
# epochs:[1],iteration:[750]/[1000],loss:0.213
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[1000],loss:0.213
# epochs:[2],iteration:[250]/[1000],loss:0.205
# epochs:[2],iteration:[500]/[1000],loss:0.207
# epochs:[2],iteration:[750]/[1000],loss:0.209
# The 4 th epoch is:
# epochs:[3],iteration:[0]/[1000],loss:0.210
# epochs:[3],iteration:[250]/[1000],loss:0.202
# epochs:[3],iteration:[500]/[1000],loss:0.204
# epochs:[3],iteration:[750]/[1000],loss:0.206
# The 5 th epoch is:
# epochs:[4],iteration:[0]/[1000],loss:0.207
# epochs:[4],iteration:[250]/[1000],loss:0.199
# epochs:[4],iteration:[500]/[1000],loss:0.202
# ...

# %%
main(contact = True, overlap=True,m=8,stride = 4,s=10)
# Out:
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[1000],loss:1.940
# epochs:[0],iteration:[250]/[1000],loss:0.332
# epochs:[0],iteration:[500]/[1000],loss:0.251
# epochs:[0],iteration:[750]/[1000],loss:0.232
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[1000],loss:0.225
# epochs:[1],iteration:[250]/[1000],loss:0.213
# epochs:[1],iteration:[500]/[1000],loss:0.212
# epochs:[1],iteration:[750]/[1000],loss:0.212
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[1000],loss:0.214
# epochs:[2],iteration:[250]/[1000],loss:0.207
# epochs:[2],iteration:[500]/[1000],loss:0.206
# epochs:[2],iteration:[750]/[1000],loss:0.209
# The 4 th epoch is:
# epochs:[3],iteration:[0]/[1000],loss:0.210
# epochs:[3],iteration:[250]/[1000],loss:0.202
# epochs:[3],iteration:[500]/[1000],loss:0.203
# epochs:[3],iteration:[750]/[1000],loss:0.208
# The 5 th epoch is:
# epochs:[4],iteration:[0]/[1000],loss:0.208
# epochs:[4],iteration:[250]/[1000],loss:0.199
# epochs:[4],iteration:[500]/[1000],loss:0.201
# ...

# %%
main(contact = True, overlap=True,m=8,stride = 4,s=10,epoches=3)
# Out:
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[1000],loss:1.880
# epochs:[0],iteration:[250]/[1000],loss:0.276
# epochs:[0],iteration:[500]/[1000],loss:0.244
# epochs:[0],iteration:[750]/[1000],loss:0.231
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[1000],loss:0.225
# epochs:[1],iteration:[250]/[1000],loss:0.216
# epochs:[1],iteration:[500]/[1000],loss:0.213
# epochs:[1],iteration:[750]/[1000],loss:0.215
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[1000],loss:0.213
# epochs:[2],iteration:[250]/[1000],loss:0.207
# epochs:[2],iteration:[500]/[1000],loss:0.208
# epochs:[2],iteration:[750]/[1000],loss:0.210

# %%
main(contact = True, overlap=True,m=8,stride = 4,s=5)
# Out:
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[1000],loss:1.982
# epochs:[0],iteration:[250]/[1000],loss:0.419
# epochs:[0],iteration:[500]/[1000],loss:0.371
# epochs:[0],iteration:[750]/[1000],loss:0.316
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[1000],loss:0.275
# epochs:[1],iteration:[250]/[1000],loss:0.256
# epochs:[1],iteration:[500]/[1000],loss:0.250
# epochs:[1],iteration:[750]/[1000],loss:0.245
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[1000],loss:0.246
# epochs:[2],iteration:[250]/[1000],loss:0.250
# epochs:[2],iteration:[500]/[1000],loss:0.237
# epochs:[2],iteration:[750]/[1000],loss:0.236
# The 4 th epoch is:
# epochs:[3],iteration:[0]/[1000],loss:0.239
# epochs:[3],iteration:[250]/[1000],loss:0.233
# epochs:[3],iteration:[500]/[1000],loss:0.228
# epochs:[3],iteration:[750]/[1000],loss:0.229
# The 5 th epoch is:
# epochs:[4],iteration:[0]/[1000],loss:0.231
# epochs:[4],iteration:[250]/[1000],loss:0.224
# epochs:[4],iteration:[500]/[1000],loss:0.225
# ...

# %%
main_2(contact = True, col=False, overlap=True,m=8,stride = 4,epoches=3,sub=True,step=5)
# Out:
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.952
# c:\Users\18120\Desktop\ENCODER\plotting.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(X).float()
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.025
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.021
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.875
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.025
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.020
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.528
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.029
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.027
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.997
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.030
# ...

# %%
main_2(contact = True, col=False, overlap=True,m=8,stride = 4,epoches=3,sub=True,step=8)
# Out:
# The 1 th epoch is:
# c:\Users\18120\Desktop\ENCODER\plotting.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(X).float()
# epochs:[0],iteration:[0]/[200],loss:0.805
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.025
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.020
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.647
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.027
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.025
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.583
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.029
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.027
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.791
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.029
# ...

# %%
main_2(contact = True, col=False, overlap=True,m=8,stride = 4,epoches=3,sub=True,step=15)
# Out:
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.850
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.024
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.020
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.447
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.027
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.024
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.590
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.031
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.027
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:0.787
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.030
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.027
# The 1 th epoch is:
# epochs:[0],iteration:[0]/[200],loss:1.101
# The 2 th epoch is:
# epochs:[1],iteration:[0]/[200],loss:0.030
# The 3 th epoch is:
# epochs:[2],iteration:[0]/[200],loss:0.028
# The 1 th epoch is:
# ...

# %% [markdown]
# observe at step 8, the model can't perform well;
# if step too close, can't well learn pattern well;
